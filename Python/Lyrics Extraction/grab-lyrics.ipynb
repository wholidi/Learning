# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pip install requests beautifulsoup4 pypinyin deep-translator
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.10/dist-packages (0.53.0)
# Requirement already satisfied: deep-translator in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
from pypinyin import lazy_pinyin
from deep_translator import GoogleTranslator

# %%
# Step 1: Define the URL (Modify for your song)
URL = "https://www.top10pinyinlyrics.com/2025/02/first-frost-bai-jing-ting-yin-xing-ren.html"

# Step 2: Fetch the webpage content
response = requests.get(URL)
if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")

    # Step 3: Locate the lyrics container (Modify selector if needed)
    lyrics_div = soup.find("div", class_="post-body")  # Modify based on actual webpage structure

    if lyrics_div:
        chinese_lyrics = lyrics_div.get_text(separator="\n", strip=True)

        # Step 4: Convert Chinese lyrics to Pinyin using pypinyin
        chinese_lines = chinese_lyrics.split("\n")
        pinyin_lyrics = [" ".join(lazy_pinyin(line)) for line in chinese_lines]

        # Step 5: Translate lyrics to English using Deep Translator
        translator = GoogleTranslator(source="zh-CN", target="en")  # Use 'zh-TW' for Traditional Chinese
        english_lyrics = [translator.translate(line) for line in chinese_lines]

# %%
# Step 6: Save the structured lyrics (Chinese + Pinyin + English) without duplicates
formatted_lyrics = []
unique_lines = set()  # To store and check for duplicate lines

for i in range(len(chinese_lines)):
    # Ensure no NoneType values exist
    chinese = chinese_lines[i] if chinese_lines[i] else ""
    pinyin = pinyin_lyrics[i] if pinyin_lyrics[i] else ""
    english = english_lyrics[i] if english_lyrics[i] else ""

    # Convert to a set to remove duplicates
    line_set = {chinese, pinyin, english}

    # Ensure all values are strings and join without duplicates
    clean_lines = "\n".join(filter(None, line_set))  # `filter(None, line_set)` removes empty strings

    if clean_lines not in unique_lines:  # Prevent duplicate block writing
        formatted_lyrics.append(clean_lines)
        unique_lines.add(clean_lines)

# Convert list to string
final_lyrics = "\n\n".join(formatted_lyrics)

# Print the cleaned lyrics
print("✅ Extracted Lyrics (No Duplicates):\n")
print(final_lyrics)

# Step 7: Save lyrics to a file
with open("formatted_lyrics_cleaned.txt", "w", encoding="utf-8") as file:
    file.write(final_lyrics)

print("\n🎵 Cleaned Lyrics saved to 'formatted_lyrics_cleaned.txt'!")
# Out:
# ✅ Extracted Lyrics (No Duplicates):
#
# English Translation, pinyin lyrics: Bai Jing Ting  Bai Jingting sings for the OST of First Frost It’s hard to coax.
# English Translation, pinyin lyrics: Bai Jing Ting   bai jing ting  sings for the OST of First Frost  nan hong .
# English Translation, pinyin lyrics: Bai Jing Ting  白敬亭 sings for the OST of First Frost 难哄.
#
# Other First Frost OST songs
#
# HERE
#
# wu lun ni ken huo bu ken   wo dou xuan ze deng
# Whether you want to or not, I will choose to wait
# 无论你肯或不肯 我都选择等
#
# Wúlùn nǐ kěn huò bù kěn  wǒ doū xuǎnzé děng
# Wúlùn nǐ kěn huò bù kěn wǒ doū xuǎnzé děng
#
# (Whether you are willing or not, I will choose to wait)
#
# deng dao ni jie shu hao jiu    tan xian de lv cheng
# 等到你结束好久  探险的旅程
# Wait until you end your long adventure journey
#
# děngdào nǐ jiéshù hǎojiǔ tànxiǎn de lǚchéng
# děngdào nǐ jiéshù hǎojiǔ  tànxiǎn de lǚchéng
#
# ( Wait till you finish your long adventurous journey)
# ( Wait till you finish your long adventure journey)
#
# If there is no loneliness
# 要是没有寂寞陪衬
# yao shi mei you ji mo pei chen
#
# yàoshi méiyǒu jìmò péichèn
#
# (If there is no loneliness to accompany you)
#
# mei you tu zhong de hui chen
# 没有途中的灰尘
# No dust on the way
#
# méiyǒu túzhōng de huīchén
#
# (No dust along the way)
#
# 你怎会向往家门
# ni zen hui xiang wang jia men
# How could you yearn for your home
#
# nǐ zěn huì xiàngwǎng jiāmén
#
# (Why would you yearn for home?)
# (Why would you year for home?)
#
# The more sincere you want to be
# 你越是想要诚恳
# ni yue shi xiang yao cheng ken
#
# nǐ yuè shì xiǎng yào chéngkěn
#
# (When you want to be more since)
# (When you want to be more sincere)
#
# 其实越残忍
# In fact, the more cruel
# qi shi yue can ren
#
# qíshí yuè cánrěn
#
# (Actually you become more cruel)
#
# 伪装不了你对我 漠视的眼神
# wei zhuang bu liao ni dui wo   mo shi de yan shen
# Can't disguise your indifferent eyes
#
# wèizhuāng bùliǎo nǐ duì wǒ mòshì de yǎnshén
#
# (
#
# Can't hide that you have an indifferent look in your eyes towards me)
# Can't hide that you have an independent look in your eyes towards me)
#
# ni bu xu wo ting xin yong heng
# 你不许我听信永恒
# You don't allow me to believe in eternal
#
# nǐ bùxǔ wǒ tīngxìn yǒnghéng
#
# (You won't let me believe in eternity)
#
# bu xu wo mi xin wo men
# 不许我迷信我们
# Don't believe in us
#
# bùxǔ wǒ míxìn wǒmen
#
# Don't allow me be superstitious about us)
#
# bu xu wo fen bu gu shen
# 不许我奋不顾身
# Don't let me rush to death
#
# bùxǔ wǒ fènbùgùshēn
#
# (Don't let me risk my life)
#
# Want to become invisible
# duo xiang hua cheng yin xing de ren
# 多想化成隐形的人
#
# duō xiǎng huàchéng yǐnxíng de rén
#
# (I really wish to become invisible)
#
# yan shi wo shang hen
# 掩饰我伤痕
# Cover my scars
#
# yǎnshì wǒ shānghén
#
# ( To hide my scars)
#
# 给你我的体温 好帮你驱走寒冷
# Give you my temperature to help you drive away the cold
# gei ni wo de ti wen   hao bang ni qu zou han leng
#
# gěi nǐ wǒ de tǐwēn  hǎo bāng nǐ qū zǒu hánlěng
#
# (Give you my body warmth, to help you drive away the cold)
#
# 看不见也能感受心疼
# kan bu jian ye neng gan shou xin teng
# You can feel heartache even if you can't see it
#
# kàn bùjiàn yěnéng gǎnshòu xīnténg
# kàn bùjiàn yě néng gǎnshòu xīnténg
#
# (I can't see but I can feel the pain)
#
# wo xiang hua cheng   yin xing de ren
# 我想化成 隐形的人
# I want to become an invisible person
#
# wǒ xiǎng huàchéng yǐnxíng de rén
#
# (I want to become an invisible person)
#
# yin cang wo de   lei zai fan gun
# 隐藏我的 泪在翻滚
# Hiding mine, tears are rolling
#
# yǐncáng wǒ de lèi zài fāngǒn
# yǐncáng wǒ de lèi zài fāngǔn
#
# (Hiding my rolling tears)
#
# wo zai ni ling luan shi jie   liu xia de zhi wen
# My fingerprints left in your messy world
# 我在你凌乱世界 留下的指纹
#
# wǒ zài nǐ língluàn shìjiè liú xià de zhǐwén
#
# (In your messy world, the fingerprints I leave behind)
#
# dui ni shi mei xin tiao de yi ge wen
# A kiss that doesn't beat you
# 对你是没心跳的一个吻
#
# duì nǐ shì méi xīntiào de yīgè wěn
#
# (To you, it's a kiss without a heartbeat)
#
# peng you dou yu xin bu ren   ze bei wo yu chun
# 朋友都于心不忍 责备我愚蠢
# My friends can't bear it and blame me for being stupid
#
# péngyǒu dōu yú xīn bùrěn zé bèi wǒ yúchǔn
#
# (Friends can't bear to blow me for being stupid)
# (Friends can't bear to blame me for being stupid)
#
# But they all avoided my persistent eyes
# 但他们都回避我 执着的眼神
# dan ta men dou hui bi wo   zhi zhuo de yan shen
#
# dàn tāmen dōu huíbì wǒ zhízhuó de yǎnshén
#
# (But they avoid my persistent look in the eyes)
#
# ke zhi wo dui ai de qian cheng
# 可知我对爱的虔诚
# Can you tell me my devotion to love
#
# kězhī wǒ duì ài de qiánchéng
# kězhī wǒduì ài de qiánchéng
#
# (Do they know my devotion to love)
#
# ke zhi wo mi xin wo men
# Can you tell that I believe in us
# 可知我迷信我们
#
# kězhī wǒ míxìn wǒmen
#
# (Do they know I'm superstitious about us)
#
# 可知我难得放任
# ke zhi wo nan de fang ren
# It's rare for me to let go
#
# kězhī wǒ nándé fàngrèn
#
# (Do they know I rarely let go)
#
# 🎵 Cleaned Lyrics saved to 'formatted_lyrics_cleaned.txt'!

# %%
# Step 6: Save the structured lyrics (Chinese + Pinyin + Single English Translation) without duplicates
formatted_lyrics = []
unique_lines = set()  # To store and check for duplicate lines

for i in range(len(chinese_lines)):
    # Ensure no NoneType values exist
    chinese = chinese_lines[i] if chinese_lines[i] else ""
    pinyin = pinyin_lyrics[i] if pinyin_lyrics[i] else ""
    english = english_lyrics[i] if english_lyrics[i] else ""

    # Avoid duplicate Pinyin variations & Keep only one English translation
    line_set = {chinese, pinyin, english}
    clean_lines = [chinese, pinyin, english]  # Maintain original order

    # Ensure unique structure and remove empty values
    clean_lines = "\n".join(filter(None, clean_lines))  # `filter(None, clean_lines)` removes empty strings

    if clean_lines not in unique_lines:  # Prevent duplicate block writing
        formatted_lyrics.append(clean_lines)
        unique_lines.add(clean_lines)

# Convert list to string
final_lyrics = "\n\n".join(formatted_lyrics)

# Print the cleaned lyrics
print("✅ Extracted Lyrics (No Duplicates, One Translation):\n")
print(final_lyrics)

# Step 7: Save lyrics to a file
with open("formatted_lyrics_cleaned.txt", "w", encoding="utf-8") as file:
    file.write(final_lyrics)

print("\n🎵 Cleaned Lyrics saved to 'formatted_lyrics_cleaned.txt'!")
# Out:
# ✅ Extracted Lyrics (No Duplicates, One Translation):
#
# English Translation, pinyin lyrics: Bai Jing Ting  白敬亭 sings for the OST of First Frost 难哄.
# English Translation, pinyin lyrics: Bai Jing Ting   bai jing ting  sings for the OST of First Frost  nan hong .
# English Translation, pinyin lyrics: Bai Jing Ting  Bai Jingting sings for the OST of First Frost It’s hard to coax.
#
# Other First Frost OST songs
# Other First Frost OST songs
# Other First Frost OST songs
#
# HERE
# HERE
# HERE
#
# 无论你肯或不肯 我都选择等
# wu lun ni ken huo bu ken   wo dou xuan ze deng
# Whether you want to or not, I will choose to wait
#
# Wúlùn nǐ kěn huò bù kěn  wǒ doū xuǎnzé děng
# Wúlùn nǐ kěn huò bù kěn  wǒ doū xuǎnzé děng
# Wúlùn nǐ kěn huò bù kěn wǒ doū xuǎnzé děng
#
# (Whether you are willing or not, I will choose to wait)
# (Whether you are willing or not, I will choose to wait)
# (Whether you are willing or not, I will choose to wait)
#
# 等到你结束好久  探险的旅程
# deng dao ni jie shu hao jiu    tan xian de lv cheng
# Wait until you end your long adventure journey
#
# děngdào nǐ jiéshù hǎojiǔ  tànxiǎn de lǚchéng
# děngdào nǐ jiéshù hǎojiǔ  tànxiǎn de lǚchéng
# děngdào nǐ jiéshù hǎojiǔ tànxiǎn de lǚchéng
#
# ( Wait till you finish your long adventurous journey)
# ( Wait till you finish your long adventurous journey)
# ( Wait till you finish your long adventure journey)
#
# 要是没有寂寞陪衬
# yao shi mei you ji mo pei chen
# If there is no loneliness
#
# yàoshi méiyǒu jìmò péichèn
# yàoshi méiyǒu jìmò péichèn
# yàoshi méiyǒu jìmò péichèn
#
# (If there is no loneliness to accompany you)
# (If there is no loneliness to accompany you)
# (If there is no loneliness to accompany you)
#
# 没有途中的灰尘
# mei you tu zhong de hui chen
# No dust on the way
#
# méiyǒu túzhōng de huīchén
# méiyǒu túzhōng de huīchén
# méiyǒu túzhōng de huīchén
#
# (No dust along the way)
# (No dust along the way)
# (No dust along the way)
#
# 你怎会向往家门
# ni zen hui xiang wang jia men
# How could you yearn for your home
#
# nǐ zěn huì xiàngwǎng jiāmén
# nǐ zěn huì xiàngwǎng jiāmén
# nǐ zěn huì xiàngwǎng jiāmén
#
# (Why would you yearn for home?)
# (Why would you yearn for home?)
# (Why would you year for home?)
#
# 你越是想要诚恳
# ni yue shi xiang yao cheng ken
# The more sincere you want to be
#
# nǐ yuè shì xiǎng yào chéngkěn
# nǐ yuè shì xiǎng yào chéngkěn
# nǐ yuè shì xiǎng yào chéngkěn
#
# (When you want to be more sincere)
# (When you want to be more sincere)
# (When you want to be more since)
#
# 其实越残忍
# qi shi yue can ren
# In fact, the more cruel
#
# qíshí yuè cánrěn
# qíshí yuè cánrěn
# qíshí yuè cánrěn
#
# (Actually you become more cruel)
# (Actually you become more cruel)
# (Actually you become more cruel)
#
# 伪装不了你对我 漠视的眼神
# wei zhuang bu liao ni dui wo   mo shi de yan shen
# Can't disguise your indifferent eyes
#
# wèizhuāng bùliǎo nǐ duì wǒ mòshì de yǎnshén
# wèizhuāng bùliǎo nǐ duì wǒ mòshì de yǎnshén
# wèizhuāng bùliǎo nǐ duì wǒ mòshì de yǎnshén
#
# (
# (
#
# Can't hide that you have an indifferent look in your eyes towards me)
# Can't hide that you have an indifferent look in your eyes towards me)
# Can't hide that you have an independent look in your eyes towards me)
#
# 你不许我听信永恒
# ni bu xu wo ting xin yong heng
# You don't allow me to believe in eternal
#
# nǐ bùxǔ wǒ tīngxìn yǒnghéng
# nǐ bùxǔ wǒ tīngxìn yǒnghéng
# nǐ bùxǔ wǒ tīngxìn yǒnghéng
#
# (You won't let me believe in eternity)
# (You won't let me believe in eternity)
# (You won't let me believe in eternity)
#
# 不许我迷信我们
# bu xu wo mi xin wo men
# Don't believe in us
#
# bùxǔ wǒ míxìn wǒmen
# bùxǔ wǒ míxìn wǒmen
# bùxǔ wǒ míxìn wǒmen
#
# Don't allow me be superstitious about us)
# Don't allow me be superstitious about us)
# Don't allow me be superstitious about us)
#
# 不许我奋不顾身
# bu xu wo fen bu gu shen
# Don't let me rush to death
#
# bùxǔ wǒ fènbùgùshēn
# bùxǔ wǒ fènbùgùshēn
# bùxǔ wǒ fènbùgùshēn
#
# (Don't let me risk my life)
# (Don't let me risk my life)
# (Don't let me risk my life)
#
# 多想化成隐形的人
# duo xiang hua cheng yin xing de ren
# Want to become invisible
#
# duō xiǎng huàchéng yǐnxíng de rén
# duō xiǎng huàchéng yǐnxíng de rén
# duō xiǎng huàchéng yǐnxíng de rén
#
# (I really wish to become invisible)
# (I really wish to become invisible)
# (I really wish to become invisible)
#
# 掩饰我伤痕
# yan shi wo shang hen
# Cover my scars
#
# yǎnshì wǒ shānghén
# yǎnshì wǒ shānghén
# yǎnshì wǒ shānghén
#
# ( To hide my scars)
# ( To hide my scars)
# ( To hide my scars)
#
# 给你我的体温 好帮你驱走寒冷
# gei ni wo de ti wen   hao bang ni qu zou han leng
# Give you my temperature to help you drive away the cold
#
# gěi nǐ wǒ de tǐwēn  hǎo bāng nǐ qū zǒu hánlěng
# gěi nǐ wǒ de tǐwēn  hǎo bāng nǐ qū zǒu hánlěng
# gěi nǐ wǒ de tǐwēn  hǎo bāng nǐ qū zǒu hánlěng
#
# (Give you my body warmth, to help you drive away the cold)
# (Give you my body warmth, to help you drive away the cold)
# (Give you my body warmth, to help you drive away the cold)
#
# 看不见也能感受心疼
# kan bu jian ye neng gan shou xin teng
# You can feel heartache even if you can't see it
#
# kàn bùjiàn yě néng gǎnshòu xīnténg
# kàn bùjiàn yě néng gǎnshòu xīnténg
# kàn bùjiàn yěnéng gǎnshòu xīnténg
#
# (I can't see but I can feel the pain)
# (I can't see but I can feel the pain)
# (I can't see but I can feel the pain)
#
# 我想化成 隐形的人
# wo xiang hua cheng   yin xing de ren
# I want to become an invisible person
#
# wǒ xiǎng huàchéng yǐnxíng de rén
# wǒ xiǎng huàchéng yǐnxíng de rén
# wǒ xiǎng huàchéng yǐnxíng de rén
#
# (I want to become an invisible person)
# (I want to become an invisible person)
# (I want to become an invisible person)
#
# 隐藏我的 泪在翻滚
# yin cang wo de   lei zai fan gun
# Hiding mine, tears are rolling
#
# yǐncáng wǒ de lèi zài fāngǔn
# yǐncáng wǒ de lèi zài fāngǔn
# yǐncáng wǒ de lèi zài fāngǒn
#
# (Hiding my rolling tears)
# (Hiding my rolling tears)
# (Hiding my rolling tears)
#
# 我在你凌乱世界 留下的指纹
# wo zai ni ling luan shi jie   liu xia de zhi wen
# My fingerprints left in your messy world
#
# wǒ zài nǐ língluàn shìjiè liú xià de zhǐwén
# wǒ zài nǐ língluàn shìjiè liú xià de zhǐwén
# wǒ zài nǐ língluàn shìjiè liú xià de zhǐwén
#
# (In your messy world, the fingerprints I leave behind)
# (In your messy world, the fingerprints I leave behind)
# (In your messy world, the fingerprints I leave behind)
#
# 对你是没心跳的一个吻
# dui ni shi mei xin tiao de yi ge wen
# A kiss that doesn't beat you
#
# duì nǐ shì méi xīntiào de yīgè wěn
# duì nǐ shì méi xīntiào de yīgè wěn
# duì nǐ shì méi xīntiào de yīgè wěn
#
# (To you, it's a kiss without a heartbeat)
# (To you, it's a kiss without a heartbeat)
# (To you, it's a kiss without a heartbeat)
#
# 朋友都于心不忍 责备我愚蠢
# peng you dou yu xin bu ren   ze bei wo yu chun
# My friends can't bear it and blame me for being stupid
#
# péngyǒu dōu yú xīn bùrěn zé bèi wǒ yúchǔn
# péngyǒu dōu yú xīn bùrěn zé bèi wǒ yúchǔn
# péngyǒu dōu yú xīn bùrěn zé bèi wǒ yúchǔn
#
# (Friends can't bear to blame me for being stupid)
# (Friends can't bear to blame me for being stupid)
# (Friends can't bear to blow me for being stupid)
#
# 但他们都回避我 执着的眼神
# dan ta men dou hui bi wo   zhi zhuo de yan shen
# But they all avoided my persistent eyes
#
# dàn tāmen dōu huíbì wǒ zhízhuó de yǎnshén
# dàn tāmen dōu huíbì wǒ zhízhuó de yǎnshén
# dàn tāmen dōu huíbì wǒ zhízhuó de yǎnshén
#
# (But they avoid my persistent look in the eyes)
# (But they avoid my persistent look in the eyes)
# (But they avoid my persistent look in the eyes)
#
# 可知我对爱的虔诚
# ke zhi wo dui ai de qian cheng
# Can you tell me my devotion to love
#
# kězhī wǒ duì ài de qiánchéng
# kězhī wǒ duì ài de qiánchéng
# kězhī wǒduì ài de qiánchéng
#
# (Do they know my devotion to love)
# (Do they know my devotion to love)
# (Do they know my devotion to love)
#
# 可知我迷信我们
# ke zhi wo mi xin wo men
# Can you tell that I believe in us
#
# kězhī wǒ míxìn wǒmen
# kězhī wǒ míxìn wǒmen
# kězhī wǒ míxìn wǒmen
#
# (Do they know I'm superstitious about us)
# (Do they know I'm superstitious about us)
# (Do they know I'm superstitious about us)
#
# 可知我难得放任
# ke zhi wo nan de fang ren
# It's rare for me to let go
#
# kězhī wǒ nándé fàngrèn
# kězhī wǒ nándé fàngrèn
# kězhī wǒ nándé fàngrèn
#
# (Do they know I rarely let go)
# (Do they know I rarely let go)
# (Do they know I rarely let go)
#
# 🎵 Cleaned Lyrics saved to 'formatted_lyrics_cleaned.txt'!
