# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
data = pd.read_csv("eurusd.csv", parse_dates = ["Date"], index_col = "Date")

# %%
data
# Out:
#                price
# Date
# 2004-01-01  1.258194
# 2004-01-02  1.258194
# 2004-01-05  1.268698
# 2004-01-06  1.272103
# 2004-01-07  1.264095
# ...              ...
# 2020-06-24  1.131235
# 2020-06-25  1.125087
# 2020-06-26  1.122208
# 2020-06-29  1.122586
# 2020-06-30  1.124720
#
# [4275 rows x 1 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of                price
# Date
# 2004-01-01  1.258194
# 2004-01-02  1.258194
# 2004-01-05  1.268698
# 2004-01-06  1.272103
# 2004-01-07  1.264095
# ...              ...
# 2020-06-24  1.131235
# 2020-06-25  1.125087
# 2020-06-26  1.122208
# 2020-06-29  1.122586
# 2020-06-30  1.124720
#
# [4275 rows x 1 columns]>

# %%
data.plot(figsize = (12, 8), title = "EUR/USD", fontsize = 12)
plt.show()

# %%
##Defining an RSI Strategy (Part 1)

# %%
data
# Out:
#                price
# Date
# 2004-01-01  1.258194
# 2004-01-02  1.258194
# 2004-01-05  1.268698
# 2004-01-06  1.272103
# 2004-01-07  1.264095
# ...              ...
# 2020-06-24  1.131235
# 2020-06-25  1.125087
# 2020-06-26  1.122208
# 2020-06-29  1.122586
# 2020-06-30  1.124720
#
# [4275 rows x 1 columns]

# %%
data.price.diff()
# Out:
# Date
# 2004-01-01         NaN
# 2004-01-02    0.000000
# 2004-01-05    0.010504
# 2004-01-06    0.003405
# 2004-01-07   -0.008008
#                 ...
# 2020-06-24    0.003267
# 2020-06-25   -0.006147
# 2020-06-26   -0.002879
# 2020-06-29    0.000378
# 2020-06-30    0.002134
# Name: price, Length: 4275, dtype: float64

# %%
data["U"] = np.where(data.price.diff() > 0, data.price.diff(), 0)

# %% [markdown]
# U:
#
# if positive price change ("up"): price change
# if negative price change ("down"): 0

# %%
data["D"] = np.where(data.price.diff() < 0, -data.price.diff(), 0)

# %% [markdown]
# D:
#
# if positive price change ("up"): 0
# if negative price change ("down"): -price change

# %%
data
# Out:
#                price         D      Diff         U
# Date
# 2004-01-01  1.258194  0.000000  0.000000  0.000000
# 2004-01-02  1.258194  0.000000  0.000000  0.000000
# 2004-01-05  1.268698  0.000000  0.000000  0.010504
# 2004-01-06  1.272103  0.000000  0.000000  0.003405
# 2004-01-07  1.264095  0.008008  0.008008  0.000000
# ...              ...       ...       ...       ...
# 2020-06-24  1.131235  0.000000  0.000000  0.003267
# 2020-06-25  1.125087  0.006147  0.006147  0.000000
# 2020-06-26  1.122208  0.002879  0.002879  0.000000
# 2020-06-29  1.122586  0.000000  0.000000  0.000378
# 2020-06-30  1.124720  0.000000  0.000000  0.002134
#
# [4275 rows x 4 columns]

# %%
##Calculate Moving Averages for U and D (alternative: exponential smoothing)

# %%
periods = 20

# %%
data["U"] = np.where(data.price.diff() > 0, data.price.diff(), 0)

# %%
data["MA_U"] = data.U.rolling(periods).mean()

# %%
data["MA_D"] = data.D.rolling(periods).mean()

# %%
data
# Out:
#                price         D      Diff         U      MA_U      MA_D
# Date
# 2004-01-01  1.258194  0.000000  0.000000  0.000000       NaN       NaN
# 2004-01-02  1.258194  0.000000  0.000000  0.000000       NaN       NaN
# 2004-01-05  1.268698  0.000000  0.000000  0.010504       NaN       NaN
# 2004-01-06  1.272103  0.000000  0.000000  0.003405       NaN       NaN
# 2004-01-07  1.264095  0.008008  0.008008  0.000000       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.000000  0.000000  0.003267  0.003182  0.001530
# 2020-06-25  1.125087  0.006147  0.006147  0.000000  0.003007  0.001837
# 2020-06-26  1.122208  0.002879  0.002879  0.000000  0.002696  0.001981
# 2020-06-29  1.122586  0.000000  0.000000  0.000378  0.002518  0.001981
# 2020-06-30  1.124720  0.000000  0.000000  0.002134  0.002587  0.001981
#
# [4275 rows x 6 columns]

# %%
##Calculate Relative Strength Index (RSI)

# %%
data["RSI"] = data.MA_U / (data.MA_U + data.MA_D) * 100

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                price         D      Diff         U      MA_U      MA_D  \
# Date
# 2004-01-28  1.244199  0.019496  0.019496  0.000000  0.004610  0.005310
# 2004-01-29  1.241003  0.003196  0.003196  0.000000  0.004610  0.005470
# 2004-01-30  1.246805  0.000000  0.000000  0.005802  0.004900  0.005470
# 2004-02-02  1.243302  0.003503  0.003503  0.000000  0.004375  0.005645
# 2004-02-03  1.253494  0.000000  0.000000  0.010192  0.004714  0.005645
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.000000  0.000000  0.003267  0.003182  0.001530
# 2020-06-25  1.125087  0.006147  0.006147  0.000000  0.003007  0.001837
# 2020-06-26  1.122208  0.002879  0.002879  0.000000  0.002696  0.001981
# 2020-06-29  1.122586  0.000000  0.000000  0.000378  0.002518  0.001981
# 2020-06-30  1.124720  0.000000  0.000000  0.002134  0.002587  0.001981
#
#                   RSI
# Date
# 2004-01-28  46.472973
# 2004-01-29  45.736150
# 2004-01-30  47.254310
# 2004-02-02  43.663573
# 2004-02-03  45.509086
# ...               ...
# 2020-06-24  67.538713
# 2020-06-25  62.077668
# 2020-06-26  57.643190
# 2020-06-29  55.965360
# 2020-06-30  56.636052
#
# [4256 rows x 7 columns]

# %%
data.loc["2019", ["price", "RSI"]].plot(figsize = (12,8), secondary_y = "RSI")
plt.show()

# %% [markdown]
# Instruments which have had
#
# more or stronger positive changes have a higher RSI
# more or stronger negative changes have a lower RSI

# %%
## Defining an RSI Strategy (Part 2)

# %% [markdown]
# . "Extreme high RSI (>70) indicates overbought instrument -> sell"
# . "Extreme low RSI (<30) indicates oversold instrument -> buy"

# %%
rsi_upper = 70
rsi_lower = 30

# %%
data.loc["2010", ["RSI"]].plot(figsize = (12,8))
plt.hlines(y = rsi_upper, xmin = data.index[0], xmax = data.index[-1], label = "RSI_Upper", color = "r")
plt.hlines(y = rsi_lower, xmin = data.index[0], xmax = data.index[-1], label = "RSI_Lower", color = "g")
plt.yticks(ticks = range(0, 100, 10))
plt.legend()
plt.show()

# %%
data["position"] = np.where(data.RSI > rsi_upper, -1, np.nan) # 1. overbought -> go short

# %%
data["position"] = np.where(data.RSI < rsi_lower, 1, data.position) #2. oversold --> go long

# %%
data["position"] = data.position.fillna(0) #3. where 1& 2 isn't applicable --> neutral

# %%
data
# Out:
#                price         D      Diff         U      MA_U      MA_D  \
# Date
# 2004-01-28  1.244199  0.019496  0.019496  0.000000  0.004610  0.005310
# 2004-01-29  1.241003  0.003196  0.003196  0.000000  0.004610  0.005470
# 2004-01-30  1.246805  0.000000  0.000000  0.005802  0.004900  0.005470
# 2004-02-02  1.243302  0.003503  0.003503  0.000000  0.004375  0.005645
# 2004-02-03  1.253494  0.000000  0.000000  0.010192  0.004714  0.005645
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.000000  0.000000  0.003267  0.003182  0.001530
# 2020-06-25  1.125087  0.006147  0.006147  0.000000  0.003007  0.001837
# 2020-06-26  1.122208  0.002879  0.002879  0.000000  0.002696  0.001981
# 2020-06-29  1.122586  0.000000  0.000000  0.000378  0.002518  0.001981
# 2020-06-30  1.124720  0.000000  0.000000  0.002134  0.002587  0.001981
#
#                   RSI  position
# Date
# 2004-01-28  46.472973       0.0
# 2004-01-29  45.736150       0.0
# 2004-01-30  47.254310       0.0
# 2004-02-02  43.663573       0.0
# 2004-02-03  45.509086       0.0
# ...               ...       ...
# 2020-06-24  67.538713       0.0
# 2020-06-25  62.077668       0.0
# 2020-06-26  57.643190       0.0
# 2020-06-29  55.965360       0.0
# 2020-06-30  56.636052       0.0
#
# [4256 rows x 8 columns]

# %%
data.position.value_counts()
# Out:
#  0.0    3637
# -1.0     316
#  1.0     303
# Name: position, dtype: int64

# %%
data.loc[:, ["RSI", "position"]].plot(figsize = (12, 8), fontsize = 12, 
                                                      secondary_y = "position", title = "EUR/USD")
plt.show()

# %%
data.loc["06-2010":"07-2010", ["RSI", "position"]].plot(figsize = (12, 8), fontsize = 12,
                                                        secondary_y = "position", title = "EUR/USD")
plt.show()

# %%
##Vectorized Strategy Backtesting

# %%
data
# Out:
#                price         D      Diff         U      MA_U      MA_D  \
# Date
# 2004-01-28  1.244199  0.019496  0.019496  0.000000  0.004610  0.005310
# 2004-01-29  1.241003  0.003196  0.003196  0.000000  0.004610  0.005470
# 2004-01-30  1.246805  0.000000  0.000000  0.005802  0.004900  0.005470
# 2004-02-02  1.243302  0.003503  0.003503  0.000000  0.004375  0.005645
# 2004-02-03  1.253494  0.000000  0.000000  0.010192  0.004714  0.005645
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.000000  0.000000  0.003267  0.003182  0.001530
# 2020-06-25  1.125087  0.006147  0.006147  0.000000  0.003007  0.001837
# 2020-06-26  1.122208  0.002879  0.002879  0.000000  0.002696  0.001981
# 2020-06-29  1.122586  0.000000  0.000000  0.000378  0.002518  0.001981
# 2020-06-30  1.124720  0.000000  0.000000  0.002134  0.002587  0.001981
#
#                   RSI  position
# Date
# 2004-01-28  46.472973       0.0
# 2004-01-29  45.736150       0.0
# 2004-01-30  47.254310       0.0
# 2004-02-02  43.663573       0.0
# 2004-02-03  45.509086       0.0
# ...               ...       ...
# 2020-06-24  67.538713       0.0
# 2020-06-25  62.077668       0.0
# 2020-06-26  57.643190       0.0
# 2020-06-29  55.965360       0.0
# 2020-06-30  56.636052       0.0
#
# [4256 rows x 8 columns]

# %%
data["returns"] = np.log(data.price.div(data.price.shift(1)))

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                price         D      Diff         U      MA_U      MA_D  \
# Date
# 2004-01-29  1.241003  0.003196  0.003196  0.000000  0.004610  0.005470
# 2004-01-30  1.246805  0.000000  0.000000  0.005802  0.004900  0.005470
# 2004-02-02  1.243302  0.003503  0.003503  0.000000  0.004375  0.005645
# 2004-02-03  1.253494  0.000000  0.000000  0.010192  0.004714  0.005645
# 2004-02-04  1.253997  0.000000  0.000000  0.000503  0.004740  0.005244
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.000000  0.000000  0.003267  0.003182  0.001530
# 2020-06-25  1.125087  0.006147  0.006147  0.000000  0.003007  0.001837
# 2020-06-26  1.122208  0.002879  0.002879  0.000000  0.002696  0.001981
# 2020-06-29  1.122586  0.000000  0.000000  0.000378  0.002518  0.001981
# 2020-06-30  1.124720  0.000000  0.000000  0.002134  0.002587  0.001981
#
#                   RSI  position   returns
# Date
# 2004-01-29  45.736150       0.0 -0.002572
# 2004-01-30  47.254310       0.0  0.004665
# 2004-02-02  43.663573       0.0 -0.002814
# 2004-02-03  45.509086       0.0  0.008164
# 2004-02-04  47.471521       0.0  0.000401
# ...               ...       ...       ...
# 2020-06-24  67.538713       0.0  0.002892
# 2020-06-25  62.077668       0.0 -0.005449
# 2020-06-26  57.643190       0.0 -0.002562
# 2020-06-29  55.965360       0.0  0.000337
# 2020-06-30  56.636052       0.0  0.001899
#
# [4255 rows x 9 columns]

# %%
data["strategy"] = data.position.shift(1) * data["returns"]

# %%
data
# Out:
#                price         D      Diff         U      MA_U      MA_D  \
# Date
# 2004-01-29  1.241003  0.003196  0.003196  0.000000  0.004610  0.005470
# 2004-01-30  1.246805  0.000000  0.000000  0.005802  0.004900  0.005470
# 2004-02-02  1.243302  0.003503  0.003503  0.000000  0.004375  0.005645
# 2004-02-03  1.253494  0.000000  0.000000  0.010192  0.004714  0.005645
# 2004-02-04  1.253997  0.000000  0.000000  0.000503  0.004740  0.005244
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.000000  0.000000  0.003267  0.003182  0.001530
# 2020-06-25  1.125087  0.006147  0.006147  0.000000  0.003007  0.001837
# 2020-06-26  1.122208  0.002879  0.002879  0.000000  0.002696  0.001981
# 2020-06-29  1.122586  0.000000  0.000000  0.000378  0.002518  0.001981
# 2020-06-30  1.124720  0.000000  0.000000  0.002134  0.002587  0.001981
#
#                   RSI  position   returns  strategy
# Date
# 2004-01-29  45.736150       0.0 -0.002572       NaN
# 2004-01-30  47.254310       0.0  0.004665       0.0
# 2004-02-02  43.663573       0.0 -0.002814      -0.0
# 2004-02-03  45.509086       0.0  0.008164       0.0
# 2004-02-04  47.471521       0.0  0.000401       0.0
# ...               ...       ...       ...       ...
# 2020-06-24  67.538713       0.0  0.002892       0.0
# 2020-06-25  62.077668       0.0 -0.005449      -0.0
# 2020-06-26  57.643190       0.0 -0.002562      -0.0
# 2020-06-29  55.965360       0.0  0.000337       0.0
# 2020-06-30  56.636052       0.0  0.001899       0.0
#
# [4255 rows x 10 columns]

# %%
data.dropna(inplace = True)

# %%
ptc = 0.00007

# %%
data["trades"] = data.position.diff().fillna(0).abs()

# %%
data.trades.value_counts()
# Out:
# 0.0    3926
# 1.0     328
# Name: trades, dtype: int64

# %%
data["strategy_net"] = data.strategy - data.trades * ptc

# %%
data["creturns"] = data["returns"].cumsum().apply(np.exp)
data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)
data["cstrategy_net"] = data["strategy_net"].cumsum().apply(np.exp)

# %%
data
# Out:
#                price         D      Diff         U      MA_U      MA_D  \
# Date
# 2004-01-30  1.246805  0.000000  0.000000  0.005802  0.004900  0.005470
# 2004-02-02  1.243302  0.003503  0.003503  0.000000  0.004375  0.005645
# 2004-02-03  1.253494  0.000000  0.000000  0.010192  0.004714  0.005645
# 2004-02-04  1.253997  0.000000  0.000000  0.000503  0.004740  0.005244
# 2004-02-05  1.257197  0.000000  0.000000  0.003200  0.004229  0.005244
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.000000  0.000000  0.003267  0.003182  0.001530
# 2020-06-25  1.125087  0.006147  0.006147  0.000000  0.003007  0.001837
# 2020-06-26  1.122208  0.002879  0.002879  0.000000  0.002696  0.001981
# 2020-06-29  1.122586  0.000000  0.000000  0.000378  0.002518  0.001981
# 2020-06-30  1.124720  0.000000  0.000000  0.002134  0.002587  0.001981
#
#                   RSI  position   returns  strategy  trades  strategy_net  \
# Date
# 2004-01-30  47.254310       0.0  0.004665       0.0     0.0           0.0
# 2004-02-02  43.663573       0.0 -0.002814      -0.0     0.0          -0.0
# 2004-02-03  45.509086       0.0  0.008164       0.0     0.0           0.0
# 2004-02-04  47.471521       0.0  0.000401       0.0     0.0           0.0
# 2004-02-05  44.642922       0.0  0.002549       0.0     0.0           0.0
# ...               ...       ...       ...       ...     ...           ...
# 2020-06-24  67.538713       0.0  0.002892       0.0     0.0           0.0
# 2020-06-25  62.077668       0.0 -0.005449      -0.0     0.0          -0.0
# 2020-06-26  57.643190       0.0 -0.002562      -0.0     0.0          -0.0
# 2020-06-29  55.965360       0.0  0.000337       0.0     0.0           0.0
# 2020-06-30  56.636052       0.0  0.001899       0.0     0.0           0.0
#
#             creturns  cstrategy  cstrategy_net
# Date
# 2004-01-30  1.004676   1.000000       1.000000
# 2004-02-02  1.001852   1.000000       1.000000
# 2004-02-03  1.010066   1.000000       1.000000
# 2004-02-04  1.010471   1.000000       1.000000
# 2004-02-05  1.013050   1.000000       1.000000
# ...              ...        ...            ...
# 2020-06-24  0.911549   1.562978       1.527501
# 2020-06-25  0.906595   1.562978       1.527501
# 2020-06-26  0.904276   1.562978       1.527501
# 2020-06-29  0.904580   1.562978       1.527501
# 2020-06-30  0.906300   1.562978       1.527501
#
# [4254 rows x 15 columns]

# %%
data[["creturns", "cstrategy", "cstrategy_net"]].plot(figsize = (12,8))
plt.show()

# %%
data.loc["2020", ["creturns", "cstrategy", "cstrategy_net"]].plot(figsize = (12 , 8))
plt.show()

# %%
##Using the RSIBacktester Class

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import brute
plt.style.use("seaborn-v0_8")

# %%
pd.read_csv("forex_pairs.csv")
# Out:
#             Date  AUDEUR=X  EURUSD=X  USDGBP=X
# 0     2004-01-01   0.59780  1.258194   0.56016
# 1     2004-01-02   0.60314  1.258194   0.55751
# 2     2004-01-05   0.60467  1.268698   0.55334
# 3     2004-01-06   0.60350  1.272103   0.54906
# 4     2004-01-07   0.60728  1.264095   0.55012
# ...          ...       ...       ...       ...
# 4290  2020-06-24   0.61349  1.131235   0.79841
# 4291  2020-06-25   0.60938  1.125087   0.80561
# 4292  2020-06-26   0.61373  1.122208   0.80480
# 4293  2020-06-29   0.61128  1.122586   0.81023
# 4294  2020-06-30   0.61097  1.124720   0.81231
#
# [4295 rows x 4 columns]

# %%
from RSIBacktester import RSIBacktester as RSI

# %%
ptc = 0.00007

# %%
tester = RSI("EURUSD=X", periods = 20, rsi_upper = 70, rsi_lower = 30,
              start = "2004-01-01", end = "2020-06-30", tc = ptc)

# %%
tester
# Out:
# RSIBacktester(symbol = EURUSD=X, RSI(20, 70, 30), start = 2004-01-01, end = 2020-06-30)

# %%
tester.data
# Out:
#                price   returns         U         D      MA_U      MA_D  \
# Date
# 2004-01-01  1.258194       NaN  0.000000  0.000000       NaN       NaN
# 2004-01-02  1.258194  0.000000  0.000000  0.000000       NaN       NaN
# 2004-01-05  1.268698  0.008313  0.010504  0.000000       NaN       NaN
# 2004-01-06  1.272103  0.002681  0.003405  0.000000       NaN       NaN
# 2004-01-07  1.264095 -0.006315  0.000000  0.008008       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.002892  0.003267  0.000000  0.003182  0.001530
# 2020-06-25  1.125087 -0.005449  0.000000  0.006147  0.003007  0.001837
# 2020-06-26  1.122208 -0.002562  0.000000  0.002879  0.002696  0.001981
# 2020-06-29  1.122586  0.000337  0.000378  0.000000  0.002518  0.001981
# 2020-06-30  1.124720  0.001899  0.002134  0.000000  0.002587  0.001981
#
#                   RSI
# Date
# 2004-01-01        NaN
# 2004-01-02        NaN
# 2004-01-05        NaN
# 2004-01-06        NaN
# 2004-01-07        NaN
# ...               ...
# 2020-06-24  67.538713
# 2020-06-25  62.077668
# 2020-06-26  57.643190
# 2020-06-29  55.965360
# 2020-06-30  56.636052
#
# [4275 rows x 7 columns]

# %%
tester.test_strategy()
# Out:
# (1.527501, 0.62353)

# %%
tester.plot_results()

# %%
tester.results
# Out:
#                price   returns         U         D      MA_U      MA_D  \
# Date
# 2004-01-29  1.241003 -0.002572  0.000000  0.003196  0.004610  0.005470
# 2004-01-30  1.246805  0.004665  0.005802  0.000000  0.004900  0.005470
# 2004-02-02  1.243302 -0.002814  0.000000  0.003503  0.004375  0.005645
# 2004-02-03  1.253494  0.008164  0.010192  0.000000  0.004714  0.005645
# 2004-02-04  1.253997  0.000401  0.000503  0.000000  0.004740  0.005244
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.002892  0.003267  0.000000  0.003182  0.001530
# 2020-06-25  1.125087 -0.005449  0.000000  0.006147  0.003007  0.001837
# 2020-06-26  1.122208 -0.002562  0.000000  0.002879  0.002696  0.001981
# 2020-06-29  1.122586  0.000337  0.000378  0.000000  0.002518  0.001981
# 2020-06-30  1.124720  0.001899  0.002134  0.000000  0.002587  0.001981
#
#                   RSI  position  strategy  trades  creturns  cstrategy
# Date
# 2004-01-29  45.736150       0.0      -0.0     0.0  0.997431   1.000000
# 2004-01-30  47.254310       0.0       0.0     0.0  1.002095   1.000000
# 2004-02-02  43.663573       0.0      -0.0     0.0  0.999279   1.000000
# 2004-02-03  45.509086       0.0       0.0     0.0  1.007471   1.000000
# 2004-02-04  47.471521       0.0       0.0     0.0  1.007875   1.000000
# ...               ...       ...       ...     ...       ...        ...
# 2020-06-24  67.538713       0.0       0.0     0.0  0.909207   1.527501
# 2020-06-25  62.077668       0.0      -0.0     0.0  0.904266   1.527501
# 2020-06-26  57.643190       0.0      -0.0     0.0  0.901953   1.527501
# 2020-06-29  55.965360       0.0       0.0     0.0  0.902256   1.527501
# 2020-06-30  56.636052       0.0       0.0     0.0  0.903971   1.527501
#
# [4255 rows x 12 columns]

# %%
tester.optimize_parameters((5, 20, 1), (65, 80, 1), (20, 35, 1)) # higher vollatility
# Out:
# (array([ 6., 65., 20.]), 2.582989)

# %%
tester.plot_results()

# %%
tester.optimize_parameters((20, 50, 1), (75, 85, 1), (15, 25, 1)) # lower volatility
# Out:
# (array([26., 75., 24.]), 1.237744)

# %%
tester.plot_results()

# %%
##USD / GBP

# %%
tester = RSI("USDGBP=X", periods = 20, rsi_upper = 70, rsi_lower = 30,
              start = "2004-01-01", end = "2020-06-30", tc = 0)

# %%
tester.test_strategy()
# Out:
# (1.060393, -0.414041)

# %%
tester.plot_results()

# %%
tester.optimize_parameters((5, 20, 1), (65, 80, 1), (20, 35, 1)) # high volatility
# Out:
# (array([ 7., 66., 34.]), 1.515508)

# %%
tester.plot_results()

# %%
## Alternative Strategies and Interpretations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import brute
plt.style.use("seaborn-v0_8")
from RSIBacktester import RSIBacktester as RSI

# %%
tester = RSI("EURUSD=X", periods = 20, rsi_upper = 70, rsi_lower = 30,
              start = "2004-01-01", end = "2020-06-30", tc = 0)

# %%
alt = tester.data.dropna()
alt
# Out:
#                price   returns         U         D      MA_U      MA_D  \
# Date
# 2004-01-28  1.244199 -0.015548  0.000000  0.019496  0.004610  0.005310
# 2004-01-29  1.241003 -0.002572  0.000000  0.003196  0.004610  0.005470
# 2004-01-30  1.246805  0.004665  0.005802  0.000000  0.004900  0.005470
# 2004-02-02  1.243302 -0.002814  0.000000  0.003503  0.004375  0.005645
# 2004-02-03  1.253494  0.008164  0.010192  0.000000  0.004714  0.005645
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.002892  0.003267  0.000000  0.003182  0.001530
# 2020-06-25  1.125087 -0.005449  0.000000  0.006147  0.003007  0.001837
# 2020-06-26  1.122208 -0.002562  0.000000  0.002879  0.002696  0.001981
# 2020-06-29  1.122586  0.000337  0.000378  0.000000  0.002518  0.001981
# 2020-06-30  1.124720  0.001899  0.002134  0.000000  0.002587  0.001981
#
#                   RSI
# Date
# 2004-01-28  46.472973
# 2004-01-29  45.736150
# 2004-01-30  47.254310
# 2004-02-02  43.663573
# 2004-02-03  45.509086
# ...               ...
# 2020-06-24  67.538713
# 2020-06-25  62.077668
# 2020-06-26  57.643190
# 2020-06-29  55.965360
# 2020-06-30  56.636052
#
# [4256 rows x 7 columns]

# %% [markdown]
# Convergence:
#
# if Price reaches higher highs -> RSI reaches higher highs (confirmation)
# if Price reaches lower lows -> RSI reaches lower lows (confirmation)

# %%
alt.loc["03-2013":"06-2013", ["price", "RSI"]].plot(figsize = (12, 8), secondary_y = "RSI")
plt.show()

# %% [markdown]
# Divergence:
#
# if Price reaches higher highs -> RSI fails to reach higher highs (Bearish Divergence)
# if Price reaches lower lows -> RSI fails to reach lower lows (Bullish Divergence)

# %%
alt.loc["03-2016":"06-2016", ["price", "RSI"]].plot(figsize = (12, 8), secondary_y = "RSI")
plt.title("Bearish Divergence", fontsize = 15)
plt.show()

# %%
alt.loc["05-2012":"11-2012", ["price", "RSI"]].plot(figsize = (12, 8), secondary_y = "RSI")
plt.title("Bullish Divergence", fontsize = 15)
plt.show()
